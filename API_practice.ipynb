# %% [markdown]
# ### Practice zipping a small number of lats, longs and then unpacking the zipped tupple to see how the packing and unpacking work

# %%
#create a practice set of random lat and long combos
x = [25.12903645, 25.92017366, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
#Use the tuple() function to diplay the lat and long combos
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017366 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %% [markdown]
# ## This uses citipy. citipy uses Maxmind's Free World Cities Database
# ### When a Python file containing a script is imported to use in another Python script, the .py extension does not need to be added to the name of the file when using the import statement

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# albany au
# teahupoo pf
# mataura pf
# karamea nz
# tsihombe mg
# provideniya ru
# hun ly
# taolanaro mg
# greenville us
# kirensk ru
# vao nc
# jamestown sh
# obama jp
# illoqqortoormiut gl
# vanimo pg
# tasiilaq gl
# bluff nz
# hermanus za
# paamiut gl
# sabzevar ir
# awjilah ly
# saskylakh ru
# namibe ao
# nizhneyansk ru
# rikitea pf
# iqaluit ca
# fairbanks us
# mys shmidta ru
# hami cn
# ambanja mg
# hobyo so
# hilo us
# hermanus za
# grand river south east mu
# lufilufi ws
# binzhou cn
# kaitangata nz
# tabou ci
# izacic ba
# mandali iq
# lucea jm
# teresina br
# new norfolk au
# rikitea pf
# balikpapan id
# illoqqortoormiut gl
# westport nz
# kapaa us
# hamilton bm
# atar mr
# rikitea pf
# georgetown sh
# ugoofaaru mv
# hobart au
# klaksvik fo
# pangnirtung ca
# devonport au
# rikitea pf
# punta arenas cl
# busselton au
# san blas mx
# rikitea pf
# kahului us
# kaitangata nz
# punta arenas cl
# illoqqortoormiut gl
# oistins bb
# hermanus za
# rikitea pf
# sembakung id
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 582

# %%
#Create a set of random latitude and longitude combinations and declare each array as a variable and
#pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them (lat_lngs) with the zip() function.
lats = np.random.uniform(low=90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Make an API Call

# %%
#Import the requests library
import requests

#Import the API key
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc860d036d912c1c2fcf990dfc2b0056

# %%
#Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc860d036d912c1c2fcf990dfc2b0056&q=Boston

# %%
#Make a 'Get' request for the city weather
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
#Create an endpoint URL for a city
city_url + "&q" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
#Get the text of the 'Get' request
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":50.65,"feels_like":48.33,"temp_min":46.99,"temp_max":53.01,"pressure":1012,"humidity":62},"visibility":10000,"wind":{"speed":14.97,"deg":110},"clouds":{"all":90},"dt":1618497662,"sys":{"type":1,"id":3486,"country":"US","sunrise":1618480961,"sunset":1618529116},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
#Get the JSON text of the 'Get' request
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 50.65,
#   'feels_like': 48.33,
#   'temp_min': 46.99,
#   'temp_max': 53.01,
#   'pressure': 1012,
#   'humidity': 62},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 110},
#  'clouds': {'all': 90},
#  'dt': 1618497662,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1618480961,
#   'sunset': 1618529116},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City weather found")
else:
    print(f"City weather not found.")
# Out:
# City weather found

# %%
# Create an endpoint URL for a city. RETURNS INCORRECT PRINT
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc860d036d912c1c2fcf990dfc2b0056&q=Bston

# %%
#Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 50.65,
#   'feels_like': 48.33,
#   'temp_min': 46.99,
#   'temp_max': 53.01,
#   'pressure': 1012,
#   'humidity': 62},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 110},
#  'clouds': {'all': 90},
#  'dt': 1618497662,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1618480961,
#   'sunset': 1618529116},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
#Get the JSON data
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1618480961,
#  'sunset': 1618529116}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data['dt']
# Out:
# 1618497662

# %%
boston_data['coord']['lat']
# Out:
# 42.3584

# %%
boston_data['main']['temp_max']
# Out:
# 53.01

# %%
lat = boston_data['coord']['lat']
lng = boston_data['coord']['lon']
max_temp = boston_data['main']['temp_max']
humidity = boston_data['main']['humidity']
clouds = boston_data['clouds']['all']
wind = boston_data['wind']['speed']
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 53.01 62 90 14.97

# %%
#Import the datetime module from the datetime library
from datetime import datetime
#Get the date from the JSON file
date = boston_data['dt']
#Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 4, 15, 14, 41, 2)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-04-15 14:41:02'

# %% [markdown]
# ## (6.2.6) Multiple cities - Import Dependencies and Initialize an Empty List and Counters

# %%
#Import the datetime module from the datetime library
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []
#print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters ~ These are set at 1 because we want the first iteration of the logging for each recorded response
#and to the set to start at 1
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 12 | albany
# Processing Record 2 of Set 12 | teahupoo
# Processing Record 3 of Set 12 | mataura
# Processing Record 4 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 12 | provideniya
# Processing Record 7 of Set 12 | hun
# Processing Record 8 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 12 | greenville
# Processing Record 10 of Set 12 | kirensk
# Processing Record 11 of Set 12 | vao
# Processing Record 12 of Set 12 | jamestown
# Processing Record 13 of Set 12 | obama
# Processing Record 14 of Set 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 12 | vanimo
# Processing Record 16 of Set 12 | tasiilaq
# Processing Record 17 of Set 12 | bluff
# Processing Record 18 of Set 12 | hermanus
# Processing Record 19 of Set 12 | paamiut
# Processing Record 20 of Set 12 | sabzevar
# ...

# %%
len(city_data)
# Out:
# 540

# %%
#Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Albany  42.6001  -73.9662     54.00        69         100        1.99
# 1     Teahupoo -17.8333 -149.2667     75.20        83          20        4.61
# 2      Mataura -46.1927  168.8643     51.01        91          99        1.01
# 3  Provideniya  64.3833 -173.3000      8.49        96          65        4.90
# 4          Hun  29.1268   15.9477     86.88        14          69       11.77
# 5   Greenville  35.6127  -77.3663     66.99        82          75        6.91
# 6      Kirensk  57.7853  108.1119     21.02        93          99        4.14
# 7          Vao -22.6667  167.4833     75.15        81         100       16.89
# 8    Jamestown  42.0970  -79.2353     41.00        75          90        8.05
# 9        Obama  35.4958  135.7460     55.99        79         100        7.74
#
#   Country                 Date
# 0      US  2021-04-15 14:43:28
# 1      PF  2021-04-15 14:46:42
# ...

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
nco_city_data_df = city_data_df[new_column_order]
nco_city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Albany      US  2021-04-15 14:43:28  42.6001  -73.9662     54.00
# 1     Teahupoo      PF  2021-04-15 14:46:42 -17.8333 -149.2667     75.20
# 2      Mataura      NZ  2021-04-15 14:46:43 -46.1927  168.8643     51.01
# 3  Provideniya      RU  2021-04-15 14:46:44  64.3833 -173.3000      8.49
# 4          Hun      LY  2021-04-15 14:46:44  29.1268   15.9477     86.88
# 5   Greenville      US  2021-04-15 14:43:49  35.6127  -77.3663     66.99
# 6      Kirensk      RU  2021-04-15 14:46:46  57.7853  108.1119     21.02
# 7          Vao      NC  2021-04-15 14:46:46 -22.6667  167.4833     75.15
# 8    Jamestown      US  2021-04-15 14:43:15  42.0970  -79.2353     41.00
# 9        Obama      JP  2021-04-15 14:46:47  35.4958  135.7460     55.99
#
#    Humidity  Cloudiness  Wind Speed
# 0        69         100        1.99
# 1        83          20        4.61
# 2        91          99        1.01
# ...

# %%
#Create the output file (CSV)
output_data_file = 'weather_data/cities.csv'
#Export the city_data_df into a CSV
nco_city_data_df.to_csv(output_data_file, index_label='City_ID')

# %% [markdown]
# ## Plotting Latitude v. Temperature

# %%
#Extract relevant fields from the DataFrame for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
#Import time module
import time
#Get today's date in seconds 
#today = time.time()

#Get today's date in seconds with conversion by strftime("%x")
today = time.strftime('%x')
today

# %%
#Import time module
import time

#Build the scatter plot for latitude v max temperture
plt.scatter(lats,
           max_temps,
           edgecolor='black', linewidths=1, marker='o',
           alpha=0.8, label='Cities')

#Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime('%x'))
plt.ylabel('Max Temperture (F)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
#plt.savefig('weather_data/Fig1.png')

#show plot
plt.show()

# %%
#Build the scatter plot for latitude v max temperture
plt.scatter(lats,
           humidity,
           edgecolor='black', linewidths=1, marker='o',
           alpha=0.8, label='Cities')

#Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
#plt.savefig('weather_data/Fig2.png')

#show plot
plt.show()

# %% [markdown]
# ## Plot Latitide v Cloudiness

# %%
#Build the scatter plot for latitude v max temperture
plt.scatter(lats,
           cloudiness,
           edgecolor='black', linewidths=1, marker='o',
           alpha=0.8, label='Cities')

#Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
#plt.savefig('weather_data/Fig2.png')

#show plot
plt.show()

# %% [markdown]
# ## Plot Latitude v. Wind Speed

# %%
#Build the scatter plot for latitude v max temperture
plt.scatter(lats,
           wind_speed,
           edgecolor='black', linewidths=1, marker='o',
           alpha=0.8, label='Cities')

#Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed (mph) "+ time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
#plt.savefig('weather_data/Fig2.png')

#show plot
plt.show()

# %% [markdown]
# ## 6.4.1 Use Linear Regression to Find the Relationship Between Variables

# %% [markdown]
# ### Practice Using Linear Regression

# %%
#Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
#create an equal number of latitudes and temperatures
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")

# %%
#Calculate the regression line "y values" from the slop and intercept
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
#Import Matplotlib
import matplotlib.pyplot as plt
#Create a scatter plot of the X and y values
plt.scatter(lats, temps)
#Plot the regression line with the x-values and the y coordinagtes based on the intercept and slope
plt.plot(lats,regress_values, 'r')
#Annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize=15, color='red')
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %% [markdown]
# ## 6.4.2 Find the Correlation Between Latitude and Maximum Temperature¶

# %%
# APPARENTLY THIS FROM THE LESS ON IS ONLY AN 'EXAMPLE' 
#Perform linear regression.
#(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
#regress_values = x_values * slope + intercept

# Get the equation of the line.
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
#plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
#plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
#plt.annotate(line_eq, (10,40), fontsize=15, color="red")
#plt.xlabel('Latitude')
#plt.ylabel('Temp')
#plt.show()

# %% [markdown]
# ### Create a Linear Regression Function

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Import linregress
    from scipy.stats import linregress

# %% [markdown]
# - RUNNING THE CODE BELOW WILL NOT RESULT IN ANY OUTPUT UNTIL WE CALL THE FUNCTION WITH FIVE PARAMETERS

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regresson on hemisphere weather data.
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    #     print(f"The r-squared is: {rvalue:.3f}")
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df['Lat'] >= 0

# %%
#Returns a df with all data fitting the criteria, for latitudes greater than or equal to 0 using loc
city_data_df.loc[(city_data_df["Lat"] >= 0)]_
city_data_df.head()

# %%
#Create Norther and Southern Hemisphere DataFrames
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# - Linear Regression: Temperature

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(5,5))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-55,75))

# %% [markdown]
# - Linear Regression: Humidity

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-55,35))

# %%
# Linear regression on the Northern Hemisphere Cloudiness
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,30))

# %%
# Linear regression on the Southern Hemisphere Cloudiness
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,30))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(10,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed', 'Wind Speed',(-50,15))
